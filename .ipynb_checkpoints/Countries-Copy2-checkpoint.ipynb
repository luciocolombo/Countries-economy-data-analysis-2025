# %% [markdown]
# # 🌍 Countries Economic Analysis
#
# ### 📘 Overview
# This notebook analyzes global economic indicators to uncover relationships between GDP, inflation, and unemployment.
# The goal is to identify patterns, outliers, and potential clusters of similar countries.
#
# ---
#
# ## 📁 1. Data Overview
# - Dataset source and description
# - Number of rows, columns, and missing values
# - Data types and first look at structure
#
# 🟡 *Objective:* understand what each variable represents and ensure data consistency.
#
# ---
#
# ## 🧹 2. Data Cleaning & Preprocessing
# - Handle null values
# - Rename columns if necessary
# - Convert types (e.g., percentages to float)
# - Remove or analyze outliers
#
# 🟡 *Objective:* ensure reliable, comparable values across all countries.
#
# ---
#
# ## 📊 3. Exploratory Data Analysis (EDA)
# - Summary statistics (mean, median, range)
# - Correlation matrix (heatmap)
# - Distribution plots (GDP, Inflation, Unemployment)
# - Identify interesting relationships
#
# 🟡 *Objective:* find economic trends and variable dependencies.
#
# ---
#
# ## 📈 4. Feature Relationships
# - Scatterplots: GDP vs Inflation, GDP vs Unemployment
# - Identify if richer countries tend to have lower jobless rates
# - Regression line or correlation coefficient
#
# 🟡 *Objective:* quantify relationships and confirm intuitions with data.
#
# ---
#
# ## 🧠 5. Clustering Analysis (K-means)
# - Normalize features
# - Choose number of clusters (elbow method)
# - Visualize clusters in 2D/3D space
# - Interpret each cluster (rich–stable, poor–inflated, etc.)
#
# 🟡 *Objective:* group countries with similar economic profiles.
#
# ---
#
# ## 🌐 6. Geographic Patterns (Optional)
# - Map visualization with GDP color scale (Plotly or Tableau)
# - Highlight regional clusters
#
# 🟡 *Objective:* visualize global economic structure spatially.
#
# ---
#
# ## 💬 7. Key Insights & Findings
# - What patterns emerged from clustering?
# - Which variables drive similarity?
# - Are there outliers or special cases (e.g., oil countries)?
#
# 🟡 *Objective:* summarize findings clearly for decision-makers.
#
# ---
#
# ## ❓ 8. Questions for Further Exploration
# - What additional variables (education, exports, debt) could improve this model?
# - Are these clusters stable over time (using multi-year data)?
# - Does GDP predict inflation better than unemployment does?
# - Can we identify potential “emerging economies” based on metrics alone?
#
# 🟡 *Objective:* extend analysis with future data or more complex models.
#
# ---
#
# ## 📎 Appendix
# - Code references
# - Libraries used
# - Any issues or considerations (e.g., data limitations)
#
# ---

# %% [markdown]
# # 1) Data overview

# %%
import seaborn as sns
import pandas as pd
import numpy as np

# %%
# Install dependencies as needed:
# pip install kagglehub[pandas-datasets]
import kagglehub

# Descargar el dataset
path = kagglehub.dataset_download("ahmadfirman/world-economic-2025")

print("Ruta del dataset:", path)
# Out:
# Ruta del dataset: C:\Users\device\.cache\kagglehub\datasets\ahmadfirman\world-economic-2025\versions\1

# %%
df = pd.read_csv('./world_economics.csv')
df
# Out:
#               name              currency           capital   languages  \
# 0          Tunisia        Tunisian dinar             Tunis      Arabic
# 1          Vietnam       Vietnamese đồng             Hanoi  Vietnamese
# 2          Ecuador  United States dollar             Quito     Spanish
# 3      Puerto Rico  United States dollar          San Juan     English
# 4    United States  United States dollar  Washington, D.C.     English
# ..             ...                   ...               ...         ...
# 168  New Caledonia             CFP franc            Nouméa      French
# 169         Kosovo                  Euro          Pristina    Albanian
# 170       Malaysia     Malaysian ringgit      Kuala Lumpur     English
# 171           Fiji         Fijian dollar              Suva     English
# 172        Jamaica       Jamaican dollar          Kingston     English
#
#       latitude   longitude       area    region           subregion  \
# 0    34.000000    9.000000   163610.0    Africa     Northern Africa
# 1    16.166667  107.833333   331212.0      Asia  South-Eastern Asia
# 2    -2.000000  -77.500000   276841.0  Americas       South America
# 3    18.250000  -66.500000     8870.0  Americas           Caribbean
# 4    38.000000  -97.000000  9372610.0  Americas       North America
# ..         ...         ...        ...       ...                 ...
# 168 -21.500000  165.500000    18575.0   Oceania           Melanesia
# 169  42.666667   21.166667    10908.0    Europe    Southeast Europe
# 170   2.500000  112.500000   330803.0      Asia  South-Eastern Asia
# 171 -17.713400  178.065000    18272.0   Oceania           Melanesia
# 172  18.250000  -77.500000    10991.0  Americas           Caribbean
#
#                           borders    GDP  GDP Growth  Interest Rate  \
# 0                  ['DZA', 'LBY']     53        1.80           7.50
# 1           ['KHM', 'CHN', 'LAO']    476        6.88           4.50
# 2                  ['COL', 'PER']    125        3.46           8.50
# 3                             NaN    126         NaN            NaN
# 4                  ['CAN', 'MEX']  29185        3.00           4.50
# ..                            ...    ...         ...            ...
# 168                           NaN     10         NaN           2.00
# 169  ['ALB', 'MKD', 'MNE', 'SRB']     11         NaN            NaN
# 170         ['BRN', 'IDN', 'THA']    422        2.10           2.75
# 171                           NaN      6         NaN           0.25
# 172                           NaN     20        0.80           5.75
#
#      Inflation Rate  Jobless Rate  Gov. Budget  Debt/GDP  Current Account  \
# 0              5.30         15.70         -6.6      79.8             -2.7
# 1              3.19          2.24         -4.0      32.9              6.1
# 2              0.72          4.50         -1.9      50.6              2.8
# 3              1.20          5.70          NaN       NaN              NaN
# 4              2.70          4.20         -6.4     124.3             -3.9
# ..              ...           ...          ...       ...              ...
# 168            0.80         11.20          NaN       NaN              NaN
# 169            4.30         10.80          0.2      16.9             -9.0
# 170            1.20          3.00         -4.1      70.4              1.7
# 171           -0.40          4.30         -3.4      78.3             -8.7
# 172            3.30          3.30         -1.0      67.9              1.3
#
#      Population
# 0         11.89
# 1        101.30
# 2         17.97
# 3          3.20
# 4        341.15
# ..          ...
# 168        0.29
# 169        1.60
# 170       34.10
# 171        0.93
# 172        2.82
#
# [173 rows x 19 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 173 entries, 0 to 172
# Data columns (total 19 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             173 non-null    object
#  1   currency         173 non-null    object
#  2   capital          172 non-null    object
#  3   languages        173 non-null    object
#  4   latitude         173 non-null    float64
#  5   longitude        173 non-null    float64
#  6   area             173 non-null    float64
#  7   region           173 non-null    object
#  8   subregion        173 non-null    object
#  9   borders          149 non-null    object
#  10  GDP              173 non-null    int64
#  11  GDP Growth       101 non-null    float64
#  12  Interest Rate    162 non-null    float64
#  13  Inflation Rate   172 non-null    float64
#  14  Jobless Rate     171 non-null    float64
#  15  Gov. Budget      166 non-null    float64
#  16  Debt/GDP         165 non-null    float64
#  17  Current Account  167 non-null    float64
#  18  Population       173 non-null    float64
# dtypes: float64(11), int64(1), object(7)
# memory usage: 25.8+ KB

# %%
#% of nulls
round(df.isna().sum()/len(df)*100,0)
# Out:
# name                0.0
# currency            0.0
# capital             1.0
# languages           0.0
# latitude            0.0
# longitude           0.0
# area                0.0
# region              0.0
# subregion           0.0
# borders            14.0
# GDP                 0.0
# GDP Growth         42.0
# Interest Rate       6.0
# Inflation Rate      1.0
# Jobless Rate        1.0
# Gov. Budget         4.0
# Debt/GDP            5.0
# Current Account     3.0
# Population          0.0
# dtype: float64

# %%
df[['name','GDP']].sort_values('GDP')
# Out:
#               name    GDP
# 22         Burundi      2
# 63         Lesotho      2
# 125        Eritrea      2
# 118     Seychelles      2
# 96         Comoros      2
# ..             ...    ...
# 49           India   3913
# 152          Japan   4026
# 124        Germany   4660
# 108          China  18744
# 4    United States  29185
#
# [173 rows x 2 columns]

# %%
#sns.barplot(data=df.sort_values('GDP'), x='name', y='GDP')
import matplotlib.pyplot as plt
df1 = pd.concat([
    
    df.nlargest(10,'GDP'),
    df.nsmallest(10,'GDP')
])

plt.figure(figsize=[15,5]);
plt.xticks(rotation=45);
sns.barplot(data=df1,x='name',y='GDP')
# Out:
# <Axes: xlabel='name', ylabel='GDP'>

# %%
#Pupulation vs region
sns.barplot(data=df, x='region', y='Population')
# Out:
# <Axes: xlabel='region', ylabel='Population'>

# %%
sns.boxplot(data=df,x='region',y='GDP', showfliers=False)
# Out:
# <Axes: xlabel='region', ylabel='GDP'>

# %%
#average population by region
df[['region','Population']].groupby('region').mean().sort_values('Population')
# Out:
#           Population
# region
# Oceania     8.912000
# Europe     17.977073
# Africa     27.399800
# Americas   36.093793
# Asia       97.610208

# %%
#How many countries don’t have listed borders?
df[df['borders'].isnull()]['name']
# Out:
# 3              Puerto Rico
# 13                   Malta
# 34             Philippines
# 46             New Zealand
# 54                Maldives
# 68                    Cuba
# 70               Mauritius
# 74              Cape Verde
# 78                  Taiwan
# 96                 Comoros
# 106                 Cyprus
# 109              Singapore
# 118             Seychelles
# 135             Madagascar
# 139                Bahrain
# 144              Australia
# 148                Bahamas
# 151                Iceland
# 152                  Japan
# 161         Cayman Islands
# 164    Trinidad and Tobago
# 168          New Caledonia
# 171                   Fiji
# 172                Jamaica
# Name: name, dtype: object

# %%
#Which currencies are used by more than one country?
list_currencies_amount = df.groupby('currency').size()
list_currencies_amount[list_currencies_amount>1]
# Out:
# currency
# Central African CFA franc     6
# Egyptian pound                2
# Euro                         23
# Swiss franc                   2
# United States dollar          4
# West African CFA franc        7
# dtype: int64

# %%
#Is GDP growth higher on average in Asia vs Europe?

df.groupby('region')['GDP'].mean()
# Out:
# region
# Africa        54.980000
# Americas    1324.413793
# Asia         838.604167
# Europe       654.097561
# Oceania      412.200000
# Name: GDP, dtype: float64

# %%
#Do landlocked countries (borders present, no coastline) have systematically different GDP per capita than coastal countries?
sns.boxplot(x=df['borders'].notna(), y=df['GDP'], showfliers=False)
print(df['borders'].notna().sum(), 'with borders', df['borders'].isna().sum(), 'without borders')
# Out:
# 149 with borders 24 without borders

# %%
#How does inflation rate differ between high-income vs low-income regions?
sns.lineplot(data=df, x='GDP', y='Inflation Rate')
# Out:
# <Axes: xlabel='GDP', ylabel='Inflation Rate'>

# %%
#Which region has the highest average debt-to-GDP ratio?
sns.barplot(data=df, x='region', y='Debt/GDP')
# Out:
# <Axes: xlabel='region', ylabel='Debt/GDP'>

# %%
#Are larger countries (by area) also more populous on average?
df[df['name']=='Tunisia']
# Out:
#       name        currency capital languages  latitude  longitude      area  \
# 0  Tunisia  Tunisian dinar   Tunis    Arabic      34.0        9.0  163610.0
#
#    region        subregion         borders  GDP  GDP Growth  Interest Rate  \
# 0  Africa  Northern Africa  ['DZA', 'LBY']   53         1.8            7.5
#
#    Inflation Rate  Jobless Rate  Gov. Budget  Debt/GDP  Current Account  \
# 0             5.3          15.7         -6.6      79.8             -2.7
#
#    Population
# 0       11.89

# %%
#Are larger countries (by area) also more populous on average?
#sns.scatterplot(data=df[df['Population']<1000], x='area',y='Population') #chopped out outliers

df['area_bins'] = pd.cut(df['area'], bins=8, labels=[x for x in range(0,8)])
sns.boxplot(data=df, x='area_bins', y='Population', showfliers=False)
# Out:
# <Axes: xlabel='area_bins', ylabel='Population'>

# %%
#Showing different view for more clarity
sns.lineplot(data=df, x='area', y='Population')
import matplotlib.pyplot as plt
plt.xscale("log"); plt.yscale("log")

# %%
#What is the correlation between GDP per capita and jobless rate?
sns.lineplot(data=df,x='GDP',y='Jobless Rate', marker='o')
# Out:
# <Axes: xlabel='GDP', ylabel='Jobless Rate'>

# %%
#let's zoom in in 5000+ GDP and under 5000 GDP
sns.lineplot(data=df[df['GDP']<5000],x='GDP',y='Jobless Rate')
plt.xscale('log')

# %%
#Log scale only increases confusion so le'ts stick with linear by steps
sns.lineplot(data=df[df['GDP']<5000],x='GDP',y='Jobless Rate', marker='o')
# Out:
# <Axes: xlabel='GDP', ylabel='Jobless Rate'>

# %%
df['GDP_bins'] = pd.qcut(df['GDP'], q=3)
sns.boxplot(data=df, x='GDP_bins', y='Jobless Rate')
print(df['GDP_bins'].value_counts().sort_index())
plt.xticks(rotation=45)
# Out:
# GDP_bins
# (1.999, 26.0]         60
# (26.0, 162.667]       55
# (162.667, 29185.0]    58
# Name: count, dtype: int64
# ([0, 1, 2],
#  [Text(0, 0, '(1.999, 26.0]'),
#   Text(1, 0, '(26.0, 162.667]'),
#   Text(2, 0, '(162.667, 29185.0]')])

# %%
#Does higher interest rate correlate with lower inflation?

sns.lineplot(data=df,x='Interest Rate', y='Inflation Rate')
# Out:
# <Axes: xlabel='Interest Rate', ylabel='Inflation Rate'>

# %%
df['Interest_Rate_bins'] = pd.qcut(df['Interest Rate'], q=5)
sns.boxplot(data=df, x='Interest_Rate_bins', y='Inflation Rate', showfliers=False)
plt.xticks(rotation=45)
print(df['Interest_Rate_bins'].value_counts())
# Out:
# Interest_Rate_bins
# (-0.001, 2.15]    34
# (2.15, 4.5]       34
# (10.2, 59.23]     33
# (6.0, 10.2]       31
# (4.5, 6.0]        30
# Name: count, dtype: int64

# %%
#How does GDP growth relate to current account balance?
plt.figure(figsize=[10,5])
sns.barplot(data=df,x='GDP Growth',y='Current Account')
plt.xticks(rotation=45);

# %%
plt.figure(figsize=[10,5])
sns.boxplot(data=df,x='GDP Growth',y='Current Account')
plt.xticks(rotation=45);

# %%
plt.figure(figsize=[10,5])
sns.scatterplot(data=df,x='GDP Growth',y='Current Account')
plt.xticks(rotation=45);

# %%
df['GDP_Growth_bins'] = pd.qcut(df['GDP Growth'],q=4)
plt.figure(figsize=[10,5])
sns.boxplot(data=df,x='GDP_Growth_bins',y='Current Account')
plt.xticks(rotation=45);

# %%
#Do countries with higher population tend to have higher GDP growth?
ds = df[df['Population']<1200]
sns.scatterplot(data=ds,x='Population',y='GDP Growth')
# Out:
# <Axes: xlabel='Population', ylabel='GDP Growth'>

# %%
df['Population_bins'] = pd.qcut(df['Population'],q=8)
sns.boxplot(data=df,x='Population_bins',y='GDP Growth', showfliers=False)
plt.xticks(rotation=45);

# %%
#Cluster countries by GDP, inflation, and jobless rate — what groups emerge?
sns.scatterplot(data=df[df['GDP']<6000],x='GDP',y='Inflation Rate', hue='Jobless Rate')
# Out:
# <Axes: xlabel='GDP', ylabel='Inflation Rate'>

# %%
#Identify outliers: countries with unusually high debt/GDP compared to their peers.
df[['Debt/GDP','name']].sort_values('Debt/GDP', ascending=False).head()
# Out:
#      Debt/GDP       name
# 17      272.0      Sudan
# 152     236.7      Japan
# 109     173.1  Singapore
# 120     164.3  Venezuela
# 117     164.1    Lebanon

# %%
sns.scatterplot(data=df[df['Debt/GDP']>164],y='Debt/GDP',x='name')
# Out:
# <Axes: xlabel='name', ylabel='Debt/GDP'>

# %%
#Which countries have both high inflation and high unemployment

# %%
from sklearn.linear_model import LinearRegression

# %%
#¿La deuda afecta el crecimiento?
sns.scatterplot(x=df['Debt/GDP'],y=df['GDP Growth'])

plt.xlabel('debt')
# Out:
# Text(0.5, 0, 'debt')

# %%
ds = df.dropna()
Y = ds['GDP Growth']
X = ds[['Debt/GDP']]
model = LinearRegression().fit(X,Y)


y = model.predict(X)

sns.lineplot(x=X['Debt/GDP'],y=y)
sns.scatterplot(x=ds['Debt/GDP'], y=ds['GDP Growth'], color="blue")

print(model.score(X,Y),
model.coef_,
model.intercept_)
# Out:
# 0.08558844166390356 [-0.03820791] 3.543512994696071

# %%
#¿La inflación impacta en la tasa de interés?
ds = df[df['Inflation Rate']<80].dropna()
X = ds[['Inflation Rate']]
Y = ds['Interest Rate']



model2 = LinearRegression().fit(X,Y)
y = model2.predict(X)
sns.lineplot(x=X['Inflation Rate'],y=y)
sns.scatterplot(x=ds['Inflation Rate'], y=Y)
model2.score(X,Y)
# Out:
# 0.6718549757229958

# %%
sns.pairplot(df)

# %%
#Demostrar que no hay relacion entre GDP y LATITUD
ds = df[df['GDP']<10000] #filter out outliers 
X = ds[['GDP']].dropna()
Y = ds['latitude'].dropna()
model3 = LinearRegression().fit(X,Y)
y = model3.predict(X)
sns.lineplot(x=X['GDP'],y=y)
sns.scatterplot(x=X['GDP'],y=Y)
print('We know it is not well predicted by a linear function', model3.coef_, model3.score(X,Y))
# Out:
# We know it is not well predicted by a linear function [0.00703025] 0.05132374344509116

# %%
#If you calculate GDP per capita (GDP / Population), which countries look strongest/weakest relative to raw GDP?
df['GDP_capita'] = df['GDP'] / df['Population']
df['Gdp_VS_GDPCapita_Ranking'] = 1/df['Population']
df[['Gdp_VS_GDPCapita_Ranking','name', 'GDP', 'GDP_capita']].sort_values('Gdp_VS_GDPCapita_Ranking')
# Out:
#      Gdp_VS_GDPCapita_Ranking            name    GDP  GDP_capita
# 108                  0.000710           China  18744   13.312500
# 49                   0.000715           India   3913    2.797798
# 4                    0.002931   United States  29185   85.548879
# 94                   0.003551       Indonesia   1396    4.957386
# 132                  0.003980        Pakistan    373    1.484459
# ..                        ...             ...    ...         ...
# 168                  3.448276   New Caledonia     10   34.482759
# 118                 10.000000      Seychelles      2   20.000000
# 161                 11.111111  Cayman Islands      7   77.777778
# 21                  25.000000   Liechtenstein      8  200.000000
# 116                 25.000000          Monaco     10  250.000000
#
# [173 rows x 4 columns]

# %%
#Cluster countries by GDP, inflation, and jobless rate — what groups emerge?
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
km_model = KMeans(n_clusters=4)
X = df[['GDP','Jobless Rate','Inflation Rate']].dropna()
Xscaled = scaler.fit_transform(X)

km_model = km_model.fit(Xscaled)

# %%
plt.figure(figsize=(15,7))
sns.scatterplot(data=X, x='GDP', y='Jobless Rate', hue=km_model.labels_, palette="Set2")
# Out:
# <Axes: xlabel='GDP', ylabel='Jobless Rate'>

# %%
plt.figure(figsize=(15,7))
sns.scatterplot(data=X, x='GDP', y='Inflation Rate', hue=km_model.labels_, palette="Set2")
# Out:
# <Axes: xlabel='GDP', ylabel='Inflation Rate'>

# %%
inertia = []
kamount = []
for k in range(1,10):
    temp_kmeans = KMeans(n_clusters=k).fit(X)
    inertia.append(temp_kmeans.inertia_)
    kamount.append(k)

sns.lineplot(x=kamount,y=inertia)
plt.xlabel('k')
plt.ylabel('inertia')
# Out:
# Text(0, 0.5, 'inertia')

# %%
df1 = df[['GDP','Jobless Rate','Inflation Rate', 'name']].dropna()
df1['cluster'] = km_model.labels_
#df1[df1['cluster']==0]
df1['cluster'].value_counts()
#We see most countries in cluster 0. Then there are 3 rare categories with exceptions
# Out:
# cluster
# 3    136
# 0     29
# 2      4
# 1      2
# Name: count, dtype: int64

# %%
#Most rare category, only two instances => The two biggest economies GDP
df1[df1['cluster']==2]
# Out:
#      GDP  Jobless Rate  Inflation Rate         name  cluster
# 17    50          20.8           146.6        Sudan        2
# 42    12          12.5           112.6  South Sudan        2
# 61    44           8.6            95.8     Zimbabwe        2
# 120  112           5.5           172.0    Venezuela        2

# %%
#Second rares, 4 instances, => Extreme inflationary countries
df1[df1['cluster']==1]
# Out:
#        GDP  Jobless Rate  Inflation Rate           name  cluster
# 4    29185           4.2             2.7  United States        1
# 108  18744           5.2             0.0          China        1

# %%
#Rare category, 27 instances => Low gdp countries, developing 
df1[df1['cluster']==3]
# Out:
#       GDP  Jobless Rate  Inflation Rate            name  cluster
# 1     476          2.24            3.19         Vietnam        3
# 2     125          4.50            0.72         Ecuador        3
# 3     126          5.70            1.20     Puerto Rico        3
# 5     540          3.00            3.10          Israel        3
# 6    3644          4.70            3.80  United Kingdom        3
# ..    ...           ...             ...             ...      ...
# 168    10         11.20            0.80   New Caledonia        3
# 169    11         10.80            4.30          Kosovo        3
# 170   422          3.00            1.20        Malaysia        3
# 171     6          4.30           -0.40            Fiji        3
# 172    20          3.30            3.30         Jamaica        3
#
# [136 rows x 5 columns]

# %%
#Most countries
df1[df1['cluster']==0]
# Out:
#      GDP  Jobless Rate  Inflation Rate                    name  cluster
# 0     53         15.70            5.30                 Tunisia        0
# 9     17         13.30            0.20             Afghanistan        0
# 11    80         29.40           19.48                  Angola        0
# 16   280         15.50           -0.60                    Iraq        0
# 18     4         25.90           -0.60                Djibouti        0
# 19    22         25.04            3.96              Mozambique        0
# 20   400         33.20            3.50            South Africa        0
# 23    14         13.40            7.20                  Rwanda        0
# 25    53         21.30            1.68                  Jordan        0
# 37    34         14.30            4.30                 Georgia        0
# 39    26         13.90            3.40                 Armenia        0
# 51    16         19.80            5.00   Republic of the Congo        0
# 63     2         16.10            4.30                 Lesotho        0
# 74     3         11.90            2.70              Cape Verde        0
# 81    20         13.00           15.87                   Syria        0
# 83    32         21.70            1.80                 Senegal        0
# 100  164         18.90           13.70                Ethiopia        0
# 101   14         11.60            3.50              Tajikistan        0
# 102   19         23.10            1.10                Botswana        0
# 117   20         11.50           14.30                 Lebanon        0
# 119   26         12.00           13.00                  Zambia        0
# 128   28         13.40            4.60  Bosnia and Herzegovina        0
# 130   47         18.60            1.70                   Libya        0
# 137   14         28.60           59.35               Palestine        0
# 143   13         19.10            3.50                 Namibia        0
# 145  154         12.80            0.50                 Morocco        0
# 156   19         17.10            0.77                   Yemen        0
# 157   25         15.10           29.60                   Haiti        0
# 162   21         20.10            0.70                   Gabon        0

# %%
import plotly.express as px
import plotly.io as pio

# aseguramos que renderice en el navegador (lo más estable)
#pio.renderers.default = "browser"

fig = px.scatter_3d(
    df1,
    x='GDP',
    y='Inflation Rate',
    z='Jobless Rate',
    color='cluster',
    hover_name='name',    # además se ve al pasar el mouse
    opacity=0.7
)

# un poco de estilo
fig.update_traces(textposition='top center')
fig.update_layout(
    legend_title="Cluster",
    scene=dict(
        xaxis_title='GDP',
        yaxis_title='Inflation Rate',
        zaxis_title='Jobless Rate'
    )
)

fig.show()
